# %%
#import the libraries
import numpy as np
import pandas as pd
import os
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
pd.set_option('display.max_colwidth', None)

# %%
df1 = pd.read_csv('angriness.csv')

# %%
df1.head()
# Out:
#                                                                                           content  \
# 0                                 Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                  Not available for busy people☺
# 2  I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                   Everything is getting expensive except some people, they are getting cheaper.
# 4                                                    My phone screen is brighter than my future 🙁
#
#    intensity
# 0  angriness
# 1  angriness
# 2  angriness
# 3  angriness
# 4  angriness

# %%
df1.shape
# Out:
# (696, 2)

# %%
df1.duplicated().sum()
# Out:
# 198

# %%
#drop the repeated tweets
#df1 = df1.drop_duplicates(subset='content', keep="last")

# %%
df1.shape
# Out:
# (696, 2)

# %%
df2 = pd.read_csv('happiness.csv')

# %%
df2.head()
# Out:
#                                                                                                                             content  \
# 0  Wants to know how the hell I can remember words to songs from years ago but can’t remember what I went into the next room for!?!
# 1                                                                         Love is a long sweet dream & marriage is an alarm clock..
# 2                                                                         The world could be amazing when you are slightly strange.
# 3                                                                       My secret talent is getting tired without doing anything. 😀
# 4                                                                         Khatarnaak Whatsapp Status Ever… Can\’t talk, wife around
#
#    intensity
# 0  happiness
# 1  happiness
# 2  happiness
# 3  happiness
# 4  happiness

# %%
df2.shape
# Out:
# (708, 2)

# %%
df2.duplicated().sum()
# Out:
# 4

# %%
#drop the repeated tweets
#df2 = df2.drop_duplicates(subset='content', keep="last")

# %%
df2.shape
# Out:
# (708, 2)

# %%
df3 = pd.read_csv('sadness.csv')

# %%
df3.head()
# Out:
#                                                                                                                                                             content  \
# 0                             Never hurt people who love you a lot, because they won’t hurt you back. But they’ll probably have no choice but to leave you forever…
# 1  Don’t expect me to tell you what you did wrong. If you can’t figure it out yourself, then you are not ready to correct it,cos you did not know it was a mistake.
# 2                                I preferred walking away than fighting for you not because you were not worth fighting for but because you never asked me to stay…
# 3                                       Moving forward in life isn’t the hard part, it’s leaving behind someone, you thought was meant to move forward with you 🙁 🙁
# 4                         Never cry for anyone in your life, because those you cry for don’t deserve your tears and those who are deserving will never let you cry.
# ...

# %%
df3.shape
# Out:
# (635, 2)

# %%
df3.duplicated().sum()
# Out:
# 245

# %%
#drop the repeated tweets
#df3 = df3.drop_duplicates(subset='content', keep="last")

# %%
df3.shape
# Out:
# (635, 2)

# %%
# Append the datasets (concatenate them row-wise)
df = pd.concat([df1, df2, df3], ignore_index=True)

# %%
df.head()
# Out:
#                                                                                           content  \
# 0                                 Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                  Not available for busy people☺
# 2  I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                   Everything is getting expensive except some people, they are getting cheaper.
# 4                                                    My phone screen is brighter than my future 🙁
#
#    intensity
# 0  angriness
# 1  angriness
# 2  angriness
# 3  angriness
# 4  angriness

# %%
df.shape
# Out:
# (2039, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2039 entries, 0 to 2038
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   content    2039 non-null   object
#  1   intensity  2039 non-null   object
# dtypes: object(2)
# memory usage: 32.0+ KB

# %%
df.isna().sum()/len(df) * 100
# Out:
# content      0.0
# intensity    0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 447

# %%
#check for the target class counts
label_dist = df['intensity'].value_counts().to_dict()
fig = plt.figure(figsize = (10, 5))
ax = plt.bar(label_dist.keys(), label_dist.values(), width=0.25)
plt.xticks([0,1,2])
plt.xlabel("Sentiment")
plt.ylabel("Content Count")
plt.show()

# %%
#check for the length of the reveiws
df['length']=df['content'].apply(lambda x: len(x.split(' ')))

# %%
df.head(10)
# Out:
#                                                                                                                                          content  \
# 0                                                                                Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                                                                 Not available for busy people☺
# 2                                                 I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                                                                  Everything is getting expensive except some people, they are getting cheaper.
# 4                                                                                                   My phone screen is brighter than my future 🙁
# ...

# %%
#avg. length for angriness, happiness and sadness reveiews
print(round(df[df['intensity']=='angriness']['length'].mean()))
print(round(df[df['intensity']=='happiness']['length'].mean()))
print(round(df[df['intensity']=='sadness']['length'].mean()))
# Out:
# 228
# 13
# 468

# %%
#plot the distribution based on the length of the reveiews for each intensity
df[df['intensity']=='angriness']['length'].plot.hist(bins=15, alpha=0.3, label="angriness")
df[df['intensity']=='happiness']['length'].plot.hist(bins=15, alpha=1, label="happiness")
df[df['intensity']=='sadness']['length'].plot.hist(bins=15, alpha=0.3, label="sadness")
plt.xlabel("length")
plt.show()

# %%
STOPWORDS = set(stopwords.words('english'))

# %%
STOPWORDS
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
# helper function to remove stopwords
df["clean_content"]=df["content"].apply(lambda x: ' '.join([word for word in x.split() if word not in (STOPWORDS)]))

# %%
df.head(10)
# Out:
#                                                                                                                                          content  \
# 0                                                                                Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                                                                 Not available for busy people☺
# 2                                                 I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                                                                  Everything is getting expensive except some people, they are getting cheaper.
# 4                                                                                                   My phone screen is brighter than my future 🙁
# ...

# %%
#helper function for content cleaning
def text_clean(content):
    #lowercase the content
    content=content.lower()
    #remove punctuation
    content = re.sub('[()!?]', ' ', content)
    content = re.sub('\[.*?\]',' ', content)
    #remove non alphanumeric occurences
    content = re.sub("[^a-z0-9]"," ", content)
    #remove the @mention
    content = re.sub("@[A-Za-z0-9_]+","", content)
    #remove the hashtags
    content = re.sub("#[A-Za-z0-9_]+","", content)
    #remove any links
    content = re.sub(r"http\S+", "", content)
    content = re.sub(r"www.\S+", "", content)
    return content

# %%
#apply the function on the tweet column
df['clean_content'] = df['clean_content'].apply(text_clean)

# %%
df.head(10)
# Out:
#                                                                                                                                          content  \
# 0                                                                                Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                                                                 Not available for busy people☺
# 2                                                 I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                                                                  Everything is getting expensive except some people, they are getting cheaper.
# 4                                                                                                   My phone screen is brighter than my future 🙁
# ...

# %%
df = df.drop('length', axis = 1)

# %%
df.head()
# Out:
#                                                                                           content  \
# 0                                 Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                  Not available for busy people☺
# 2  I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                   Everything is getting expensive except some people, they are getting cheaper.
# 4                                                    My phone screen is brighter than my future 🙁
#
#    intensity                                                 clean_content
# 0  angriness         sometimes i m angry  i m hurt there s big difference
# 1  angriness                                    not available busy people
# 2  angriness      i exist impress world  i exist live life way make happy
# 3  angriness  everything getting expensive except people  getting cheaper
# ...

# %%
#check for the length of the reveiws
df['length']=df['clean_content'].apply(lambda x: len(x.split(' ')))

# %%
df.head(5)
# Out:
#                                                                                           content  \
# 0                                 Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                  Not available for busy people☺
# 2  I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                   Everything is getting expensive except some people, they are getting cheaper.
# 4                                                    My phone screen is brighter than my future 🙁
#
#    intensity                                                 clean_content  \
# 0  angriness         sometimes i m angry  i m hurt there s big difference
# 1  angriness                                    not available busy people
# 2  angriness      i exist impress world  i exist live life way make happy
# 3  angriness  everything getting expensive except people  getting cheaper
# ...

# %%
#avg. length for angriness, happiness and sadness reveiews
print(round(df[df['intensity']=='angriness']['length'].mean()))
print(round(df[df['intensity']=='happiness']['length'].mean()))
print(round(df[df['intensity']=='sadness']['length'].mean()))
# Out:
# 11
# 10
# 9

# %%
#plot the distribution based on the length of the reveiews for each intensity
df[df['intensity']=='angriness']['length'].plot.hist(bins=15, alpha=0.3, label="angriness")
df[df['intensity']=='happiness']['length'].plot.hist(bins=15, alpha=1, label="happiness")
df[df['intensity']=='sadness']['length'].plot.hist(bins=15, alpha=0.3, label="sadness")
plt.xlabel("length")
plt.show()

# %%
#frequency count
top_words = 50
#tokenize the tweets into individual tokens
words = nltk.tokenize.word_tokenize(df['clean_content'].str.cat(sep=' '))
#list of redundant words to be not considered in the frequency count
filter_words = [word for word in words if word not in STOPWORDS]

# %%
#Use the FreqDist function from nltk for freq count
word_freq = nltk.FreqDist(filter_words)
#create the dataframe for top occuring words
wordfreq_df = pd.DataFrame(word_freq.most_common(top_words),
                    columns=['Word', 'Frequency'])

# %%
wordfreq_df
# Out:
#             Word  Frequency
# 0           love        266
# 1         people        196
# 2           life        140
# 3          never        139
# 4        someone        137
# 5      happiness        137
# 6            one        130
# 7          anger        114
# 8          angry        112
# 9           like        105
# 10         heart         84
# 11           get         83
# 12         smile         83
# 13          make         81
# 14          know         81
# 15     sometimes         80
# 16          want         80
# 17          much         71
# 18          time         71
# 19        person         70
# 20          hurt         68
# 21         happy         68
# 22          miss         68
# 23          need         67
# 24        always         66
# 25          care         62
# 26            go         60
# 27        things         58
# 28         every         56
# 29         think         56
# 30           man         52
# 31    everything         49
# ...

# %%
df['clean_content']
# Out:
# 0              sometimes i m angry  i m hurt there s big difference
# 1                                         not available busy people
# 2           i exist impress world  i exist live life way make happy
# 3       everything getting expensive except people  getting cheaper
# 4                                  my phone screen brighter future
#                                     ...
# 2034                   stop crying yesterday start smiling tomorrow
# 2035                      an eye dust  n a heart trust always cries
# 2036                                         tears come heart brain
# 2037       sometimes hold head high  blink away tears  say good bye
# 2038             instead wiping tears  wipe away people caused them
# Name: clean_content, Length: 2039, dtype: object

# %%
df.head()
# Out:
#                                                                                           content  \
# 0                                 Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                  Not available for busy people☺
# 2  I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                   Everything is getting expensive except some people, they are getting cheaper.
# 4                                                    My phone screen is brighter than my future 🙁
#
#    intensity                                                 clean_content  \
# 0  angriness         sometimes i m angry  i m hurt there s big difference
# 1  angriness                                    not available busy people
# 2  angriness      i exist impress world  i exist live life way make happy
# 3  angriness  everything getting expensive except people  getting cheaper
# ...

# %%
df["clean_content"]=df["clean_content"].apply(lambda x: ' '.join([word for word in x.split() if word not in (STOPWORDS)]))

# %%
df["clean_content"]
# Out:
# 0                              sometimes angry hurt big difference
# 1                                            available busy people
# 2               exist impress world exist live life way make happy
# 3       everything getting expensive except people getting cheaper
# 4                                     phone screen brighter future
#                                    ...
# 2034                  stop crying yesterday start smiling tomorrow
# 2035                           eye dust n heart trust always cries
# 2036                                        tears come heart brain
# 2037        sometimes hold head high blink away tears say good bye
# 2038                  instead wiping tears wipe away people caused
# Name: clean_content, Length: 2039, dtype: object

# %%
df.head()
# Out:
#                                                                                           content  \
# 0                                 Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                  Not available for busy people☺
# 2  I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                   Everything is getting expensive except some people, they are getting cheaper.
# 4                                                    My phone screen is brighter than my future 🙁
#
#    intensity                                               clean_content  \
# 0  angriness                         sometimes angry hurt big difference
# 1  angriness                                       available busy people
# 2  angriness          exist impress world exist live life way make happy
# 3  angriness  everything getting expensive except people getting cheaper
# ...

# %%
#check for the length of the reveiws
df['length']=df['clean_content'].apply(lambda x: len(x.split(' ')))

# %%
df.head()
# Out:
#                                                                                           content  \
# 0                                 Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                  Not available for busy people☺
# 2  I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                   Everything is getting expensive except some people, they are getting cheaper.
# 4                                                    My phone screen is brighter than my future 🙁
#
#    intensity                                               clean_content  \
# 0  angriness                         sometimes angry hurt big difference
# 1  angriness                                       available busy people
# 2  angriness          exist impress world exist live life way make happy
# 3  angriness  everything getting expensive except people getting cheaper
# ...

# %%
#apply the function on the tweet column
df['clean_content'] = df['clean_content'].apply(text_clean)

# %%
df['clean_content']
# Out:
# 0                              sometimes angry hurt big difference
# 1                                            available busy people
# 2               exist impress world exist live life way make happy
# 3       everything getting expensive except people getting cheaper
# 4                                     phone screen brighter future
#                                    ...
# 2034                  stop crying yesterday start smiling tomorrow
# 2035                           eye dust n heart trust always cries
# 2036                                        tears come heart brain
# 2037        sometimes hold head high blink away tears say good bye
# 2038                  instead wiping tears wipe away people caused
# Name: clean_content, Length: 2039, dtype: object

# %%
df.head()
# Out:
#                                                                                           content  \
# 0                                 Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                  Not available for busy people☺
# 2  I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                   Everything is getting expensive except some people, they are getting cheaper.
# 4                                                    My phone screen is brighter than my future 🙁
#
#    intensity                                               clean_content  \
# 0  angriness                         sometimes angry hurt big difference
# 1  angriness                                       available busy people
# 2  angriness          exist impress world exist live life way make happy
# 3  angriness  everything getting expensive except people getting cheaper
# ...

# %%
#check for the length of the reveiws
df['length']=df['clean_content'].apply(lambda x: len(x.split(' ')))

# %%
df.head()
# Out:
#                                                                                           content  \
# 0                                 Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                  Not available for busy people☺
# 2  I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                   Everything is getting expensive except some people, they are getting cheaper.
# 4                                                    My phone screen is brighter than my future 🙁
#
#    intensity                                               clean_content  \
# 0  angriness                         sometimes angry hurt big difference
# 1  angriness                                       available busy people
# 2  angriness          exist impress world exist live life way make happy
# 3  angriness  everything getting expensive except people getting cheaper
# ...

# %%
#avg. length for angriness, happiness and sadness reveiews
print(round(df[df['intensity']=='angriness']['length'].mean()))
print(round(df[df['intensity']=='happiness']['length'].mean()))
print(round(df[df['intensity']=='sadness']['length'].mean()))
# Out:
# 6
# 6
# 5

# %%
#plot the distribution based on the length of the reveiews for each intensity
df[df['intensity']=='angriness']['length'].plot.hist(bins=15, alpha=0.3, label="angriness")
df[df['intensity']=='happiness']['length'].plot.hist(bins=15, alpha=1, label="happiness")
df[df['intensity']=='sadness']['length'].plot.hist(bins=15, alpha=0.3, label="sadness")
plt.xlabel("length")
plt.show()

# %%
#Sentiment Classifier
#split the data into training and test set with balanced split based on target class
X_train, X_test, y_train, y_test = train_test_split(df["clean_content"],
                                                    df["intensity"],test_size=0.2,
                                                    stratify=df['intensity'])

# %%
#check the shape of train and test data
print(X_train.shape[0],X_test.shape[0])
# Out:
# 1631 408

# %%
#check the class balance in train data
print(y_train.value_counts())
# Out:
# intensity
# happiness    566
# angriness    557
# sadness      508
# Name: count, dtype: int64

# %%
#check the target class balance in test data
print(y_test.value_counts())
# Out:
# intensity
# happiness    142
# angriness    139
# sadness      127
# Name: count, dtype: int64

# %%
# Use the countvectoriser to convert text data into numerical/vector form
vectorizer = CountVectorizer(token_pattern=r'\b\w+\b')
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
# train using Logistic Regression Model
lr1 = LogisticRegression(class_weight='balanced')
lr1.fit(X_train_vec,y_train)
print(confusion_matrix(lr1.predict(X_test_vec),y_test))
print(classification_report(lr1.predict(X_test_vec),y_test))
# Out:
# [[86 21 12]
#  [14 93 16]
#  [39 28 99]]
#               precision    recall  f1-score   support
#
#    angriness       0.62      0.72      0.67       119
#    happiness       0.65      0.76      0.70       123
#      sadness       0.78      0.60      0.68       166
#
#     accuracy                           0.68       408
#    macro avg       0.68      0.69      0.68       408
# weighted avg       0.70      0.68      0.68       408

# %%
from sklearn.model_selection import GridSearchCV

param_gridlr1 = {
    'C': [0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'newton-cg', 'saga']
}

grid_searchlr1 = GridSearchCV(lr1, param_gridlr1, cv=5, scoring='accuracy')
grid_searchlr1.fit(X_train_vec, y_train)

# Best model
best_lr1 = grid_searchlr1.best_estimator_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
best_lr1
# Out:
# LogisticRegression(C=100, class_weight='balanced', solver='saga')

# %%
best_lr1.fit(X_train_vec, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(C=100, class_weight='balanced', solver='saga')

# %%
print(confusion_matrix(best_lr1.predict(X_test_vec),y_test))
print(classification_report(best_lr1.predict(X_test_vec),y_test))
# Out:
# [[87 20 12]
#  [14 98 18]
#  [38 24 97]]
#               precision    recall  f1-score   support
#
#    angriness       0.63      0.73      0.67       119
#    happiness       0.69      0.75      0.72       130
#      sadness       0.76      0.61      0.68       159
#
#     accuracy                           0.69       408
#    macro avg       0.69      0.70      0.69       408
# weighted avg       0.70      0.69      0.69       408

# %%
#train and evaluate the multinominal Naive Baysian Classifier model
MNB1 = MultinomialNB()
MNB1.fit(X_train_vec,y_train)
print(confusion_matrix(MNB1.predict(X_test_vec),y_test))
print(classification_report(MNB1.predict(X_test_vec),y_test))
# Out:
# [[82 22 12]
#  [33 94 37]
#  [24 26 78]]
#               precision    recall  f1-score   support
#
#    angriness       0.59      0.71      0.64       116
#    happiness       0.66      0.57      0.61       164
#      sadness       0.61      0.61      0.61       128
#
#     accuracy                           0.62       408
#    macro avg       0.62      0.63      0.62       408
# weighted avg       0.63      0.62      0.62       408

# %%
# Define the parameter grid
param_gridMNB1 = {
    'alpha': [0.01, 0.1, 0.5, 1, 5, 10]
}

# Set up the grid search with cross-validation
grid_searchMNB1 = GridSearchCV(MNB1, param_gridMNB1, cv=5, scoring='accuracy')

# Train the model using grid search
grid_searchMNB1.fit(X_train_vec, y_train)

# Get the best model
best_mnb1 = grid_searchMNB1.best_estimator_

# Evaluate the performance on the test set
print(f"Best alpha: {grid_searchMNB1.best_params_['alpha']}")
print(f"Best cross-validation accuracy: {grid_searchMNB1.best_score_}")
# Out:
# Best alpha: 5
# Best cross-validation accuracy: 0.6278775257499859

# %%
best_mnb1
# Out:
# MultinomialNB(alpha=5)

# %%
best_mnb1.fit(X_train_vec, y_train)
# Out:
# MultinomialNB(alpha=5)

# %%
print(confusion_matrix(best_mnb1.predict(X_test_vec),y_test))
print(classification_report(best_mnb1.predict(X_test_vec),y_test))
# Out:
# [[79 24 14]
#  [36 94 44]
#  [24 24 69]]
#               precision    recall  f1-score   support
#
#    angriness       0.57      0.68      0.62       117
#    happiness       0.66      0.54      0.59       174
#      sadness       0.54      0.59      0.57       117
#
#     accuracy                           0.59       408
#    macro avg       0.59      0.60      0.59       408
# weighted avg       0.60      0.59      0.59       408

# %%
#train and evaluate the RF classifier model
rf1 = RandomForestClassifier(n_estimators=100)
rf1.fit(X_train_vec,y_train)
print(confusion_matrix(rf1.predict(X_test_vec),y_test))
print(classification_report(rf1.predict(X_test_vec),y_test))
# Out:
# [[88 19 11]
#  [15 96 22]
#  [36 27 94]]
#               precision    recall  f1-score   support
#
#    angriness       0.63      0.75      0.68       118
#    happiness       0.68      0.72      0.70       133
#      sadness       0.74      0.60      0.66       157
#
#     accuracy                           0.68       408
#    macro avg       0.68      0.69      0.68       408
# weighted avg       0.69      0.68      0.68       408

# %%
# Define the parameter grid
param_grid_rf1 = {
    'n_estimators': [100, 300, 500],
    'max_depth': [10, 50, 100, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']
}

# Set up the grid search
grid_search_rf1 = GridSearchCV(estimator=rf1, param_grid=param_grid_rf1, cv=5, scoring='accuracy')

# Fit the model
grid_search_rf1.fit(X_train_vec, y_train)

# Get the best parameters and model
best_rf1 = grid_search_rf1.best_estimator_
print(f"Best parameters: {grid_search_rf1.best_params_}")
print(f"Best cross-validation accuracy: {grid_search_rf1.best_score_}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 540 fits failed out of a total of 1080.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 540 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
best_rf1
# Out:
# RandomForestClassifier(min_samples_split=10)

# %%
best_rf1.fit(X_train_vec, y_train)
# Out:
# RandomForestClassifier(min_samples_split=10)

# %%
print(confusion_matrix(best_rf1.predict(X_test_vec),y_test))
print(classification_report(best_rf1.predict(X_test_vec),y_test))
# Out:
# [[ 98  18   9]
#  [ 13 102  15]
#  [ 28  22 103]]
#               precision    recall  f1-score   support
#
#    angriness       0.71      0.78      0.74       125
#    happiness       0.72      0.78      0.75       130
#      sadness       0.81      0.67      0.74       153
#
#     accuracy                           0.74       408
#    macro avg       0.74      0.75      0.74       408
# weighted avg       0.75      0.74      0.74       408

# %%
#train and evaluate the Linear Support Vector Classifier model
SVC1 = LinearSVC()
SVC1.fit(X_train_vec,y_train)
print(confusion_matrix(SVC1.predict(X_test_vec),y_test))
print(classification_report(SVC1.predict(X_test_vec),y_test))
# Out:
# [[86 25 13]
#  [13 90 17]
#  [40 27 97]]
#               precision    recall  f1-score   support
#
#    angriness       0.62      0.69      0.65       124
#    happiness       0.63      0.75      0.69       120
#      sadness       0.76      0.59      0.67       164
#
#     accuracy                           0.67       408
#    macro avg       0.67      0.68      0.67       408
# weighted avg       0.68      0.67      0.67       408
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
# Define the parameter grid
param_grid_svc1 = {
    'C': [0.01, 0.1, 1, 10, 100]
}

# Set up the grid search
grid_search_svc1 = GridSearchCV(SVC1, param_grid_svc1, cv=5, scoring='accuracy')

# Fit the model
grid_search_svc1.fit(X_train_vec, y_train)

# Get the best model and parameters
best_svc1 = grid_search_svc1.best_estimator_
print(f"Best parameters: {grid_search_svc1.best_params_}")
print(f"Best cross-validation accuracy: {grid_search_svc1.best_score_}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
best_svc1
# Out:
# LinearSVC(C=1)

# %%
best_svc1.fit(X_train_vec, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC(C=1)

# %%
print(confusion_matrix(best_svc1.predict(X_test_vec),y_test))
print(classification_report(best_svc1.predict(X_test_vec),y_test))
# Out:
# [[86 25 13]
#  [13 90 17]
#  [40 27 97]]
#               precision    recall  f1-score   support
#
#    angriness       0.62      0.69      0.65       124
#    happiness       0.63      0.75      0.69       120
#      sadness       0.76      0.59      0.67       164
#
#     accuracy                           0.67       408
#    macro avg       0.67      0.68      0.67       408
# weighted avg       0.68      0.67      0.67       408

# %%
# Create the XGBoost classifier
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the labels to numerical format
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Fit the model
xgb_model.fit(X_train_vec, y_train_encoded)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:28:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
# ...

# %%
print(confusion_matrix(xgb_model.predict(X_test_vec),y_test_encoded))
print(classification_report(xgb_model.predict(X_test_vec),y_test_encoded))
# Out:
# [[109  16  37]
#  [ 14 101  24]
#  [ 16  25  66]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.67      0.72       162
#            1       0.71      0.73      0.72       139
#            2       0.52      0.62      0.56       107
#
#     accuracy                           0.68       408
#    macro avg       0.67      0.67      0.67       408
# weighted avg       0.69      0.68      0.68       408

# %%
# Initialize the base estimator
base_estimator = DecisionTreeClassifier(max_depth=1)  # Stump

# %%
# Create the AdaBoost classifier
ada_model = AdaBoostClassifier(n_estimators=50, random_state=42)

# %%
ada_model.fit(X_train_vec, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier(random_state=42)

# %%
print(confusion_matrix(ada_model.predict(X_test_vec),y_test))
print(classification_report(ada_model.predict(X_test_vec),y_test))
# Out:
# [[109  57  66]
#  [ 18  72  18]
#  [ 12  13  43]]
#               precision    recall  f1-score   support
#
#    angriness       0.78      0.47      0.59       232
#    happiness       0.51      0.67      0.58       108
#      sadness       0.34      0.63      0.44        68
#
#     accuracy                           0.55       408
#    macro avg       0.54      0.59      0.53       408
# weighted avg       0.64      0.55      0.56       408

# %%
# Define the Gradient Boosting model
gb = GradientBoostingClassifier()

# %%
gb.fit(X_train_vec, y_train)
# Out:
# GradientBoostingClassifier()

# %%
print(confusion_matrix(gb.predict(X_test_vec),y_test))
print(classification_report(gb.predict(X_test_vec),y_test))
# Out:
# [[116  32  47]
#  [ 10  94  22]
#  [ 13  16  58]]
#               precision    recall  f1-score   support
#
#    angriness       0.83      0.59      0.69       195
#    happiness       0.66      0.75      0.70       126
#      sadness       0.46      0.67      0.54        87
#
#     accuracy                           0.66       408
#    macro avg       0.65      0.67      0.65       408
# weighted avg       0.70      0.66      0.66       408

# %%
# Use TF-IDF Vectorizer
vectorizertfidf = TfidfVectorizer(use_idf=True, ngram_range=(1, 2))
X_train_tfvec = vectorizertfidf.fit_transform(X_train)
X_test_tfvec = vectorizertfidf.transform(X_test)

# %%
lr2 = LogisticRegression(class_weight='balanced')
lr2.fit(X_train_tfvec,y_train)
#evaluate the performance of logistic model on test data
print(confusion_matrix(lr2.predict(X_test_tfvec),y_test))
print(classification_report(lr2.predict(X_test_tfvec),y_test))
# Out:
# [[ 85  21   7]
#  [ 18 102  22]
#  [ 36  19  98]]
#               precision    recall  f1-score   support
#
#    angriness       0.61      0.75      0.67       113
#    happiness       0.72      0.72      0.72       142
#      sadness       0.77      0.64      0.70       153
#
#     accuracy                           0.70       408
#    macro avg       0.70      0.70      0.70       408
# weighted avg       0.71      0.70      0.70       408

# %%
from sklearn.model_selection import GridSearchCV

param_gridlr2 = {
    'C': [0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'newton-cg', 'saga']
}

grid_searchlr2 = GridSearchCV(lr2, param_gridlr2, cv=5, scoring='accuracy')
grid_searchlr2.fit(X_train_tfvec, y_train)

# Best model
best_lr2 = grid_searchlr2.best_estimator_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
best_lr2
# Out:
# LogisticRegression(C=1, class_weight='balanced', solver='saga')

# %%
best_lr2.fit(X_train_tfvec, y_train)
# Out:
# LogisticRegression(C=1, class_weight='balanced', solver='saga')

# %%
print(confusion_matrix(best_lr2.predict(X_test_tfvec),y_test))
print(classification_report(best_lr2.predict(X_test_tfvec),y_test))
# Out:
# [[ 85  21   7]
#  [ 18 102  22]
#  [ 36  19  98]]
#               precision    recall  f1-score   support
#
#    angriness       0.61      0.75      0.67       113
#    happiness       0.72      0.72      0.72       142
#      sadness       0.77      0.64      0.70       153
#
#     accuracy                           0.70       408
#    macro avg       0.70      0.70      0.70       408
# weighted avg       0.71      0.70      0.70       408

# %%
#train and evaluate the multinominal Naive Baysian Classifier model
MNB2 =  MultinomialNB()
MNB2.fit(X_train_tfvec,y_train)
print(confusion_matrix(MNB2.predict(X_test_tfvec),y_test))
print(classification_report(MNB2.predict(X_test_tfvec),y_test))
# Out:
# [[92 28 11]
#  [36 99 41]
#  [11 15 75]]
#               precision    recall  f1-score   support
#
#    angriness       0.66      0.70      0.68       131
#    happiness       0.70      0.56      0.62       176
#      sadness       0.59      0.74      0.66       101
#
#     accuracy                           0.65       408
#    macro avg       0.65      0.67      0.65       408
# weighted avg       0.66      0.65      0.65       408

# %%
# Define the parameter grid
param_gridMNB2 = {
    'alpha': [0.01, 0.1, 0.5, 1, 5, 10]
}

# Set up the grid search with cross-validation
grid_searchMNB2 = GridSearchCV(MNB2, param_gridMNB2, cv=5, scoring='accuracy')

# Train the model using grid search
grid_searchMNB2.fit(X_train_tfvec, y_train)

# Get the best model
best_mnb2 = grid_searchMNB2.best_estimator_

# Evaluate the performance on the test set
print(f"Best alpha: {grid_searchMNB2.best_params_['alpha']}")
print(f"Best cross-validation accuracy: {grid_searchMNB2.best_score_}")
# Out:
# Best alpha: 1
# Best cross-validation accuracy: 0.6413575730286485

# %%
best_mnb2
# Out:
# MultinomialNB(alpha=1)

# %%
best_mnb2.fit(X_train_tfvec, y_train)
# Out:
# MultinomialNB(alpha=1)

# %%
print(confusion_matrix(best_mnb2.predict(X_test_tfvec),y_test))
print(classification_report(best_mnb2.predict(X_test_tfvec),y_test))
# Out:
# [[92 28 11]
#  [36 99 41]
#  [11 15 75]]
#               precision    recall  f1-score   support
#
#    angriness       0.66      0.70      0.68       131
#    happiness       0.70      0.56      0.62       176
#      sadness       0.59      0.74      0.66       101
#
#     accuracy                           0.65       408
#    macro avg       0.65      0.67      0.65       408
# weighted avg       0.66      0.65      0.65       408

# %%
#train and evaluate the RF classifier model
rf2 = RandomForestClassifier(n_estimators=200, random_state=0)
rf2.fit(X_train_tfvec,y_train)
print(confusion_matrix(rf2.predict(X_test_tfvec),y_test))
print(classification_report(rf2.predict(X_test_tfvec),y_test))
# Out:
# [[91 21 12]
#  [15 92 24]
#  [33 29 91]]
#               precision    recall  f1-score   support
#
#    angriness       0.65      0.73      0.69       124
#    happiness       0.65      0.70      0.67       131
#      sadness       0.72      0.59      0.65       153
#
#     accuracy                           0.67       408
#    macro avg       0.67      0.68      0.67       408
# weighted avg       0.68      0.67      0.67       408

# %%
# Define the parameter grid
param_grid_rf2 = {
    'n_estimators': [100, 300, 500],
    'max_depth': [10, 50, 100, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']
}

# Set up the grid search
grid_search_rf2 = GridSearchCV(estimator=rf2, param_grid=param_grid_rf2, cv=5, scoring='accuracy')

# Fit the model
grid_search_rf2.fit(X_train_tfvec, y_train)

# Get the best parameters and model
best_rf2 = grid_search_rf2.best_estimator_
print(f"Best parameters: {grid_search_rf2.best_params_}")
print(f"Best cross-validation accuracy: {grid_search_rf2.best_score_}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-301-fd48163b9d05> in <cell line: 14>()
#      12
#      13 # Fit the model
# ---> 14 grid_search_rf2.fit(X_train_tfvec, y_train)
#      15
#      16 # Get the best parameters and model
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1017                 return results
#    1018
# -> 1019             self._run_search(evaluate_candidates)
#    1020
#    1021             # multimetric is determined here because in the case of a callable
#
# ...

# %%
best_rf2
# Out:
# RandomForestClassifier(max_depth=100, min_samples_leaf=2, random_state=0)

# %%
best_rf2.fit(X_train_tfvec,y_train)
# Out:
# RandomForestClassifier(max_depth=100, min_samples_leaf=2, random_state=0)

# %%
print(confusion_matrix(best_rf2.predict(X_test_tfvec),y_test))
print(classification_report(best_rf2.predict(X_test_tfvec),y_test))
# Out:
# [[ 91  13   9]
#  [ 23 105  18]
#  [ 25  24 100]]
#               precision    recall  f1-score   support
#
#    angriness       0.65      0.81      0.72       113
#    happiness       0.74      0.72      0.73       146
#      sadness       0.79      0.67      0.72       149
#
#     accuracy                           0.73       408
#    macro avg       0.73      0.73      0.73       408
# weighted avg       0.73      0.73      0.73       408

# %%
#train and evaluate the Linear Support Vector Classifier model
SVC2 = LinearSVC()
SVC2.fit(X_train_tfvec,y_train)
print(confusion_matrix(SVC2.predict(X_test_tfvec),y_test))
print(classification_report(SVC2.predict(X_test_tfvec),y_test))
# Out:
# [[ 90  16   7]
#  [ 17 108  26]
#  [ 32  18  94]]
#               precision    recall  f1-score   support
#
#    angriness       0.65      0.80      0.71       113
#    happiness       0.76      0.72      0.74       151
#      sadness       0.74      0.65      0.69       144
#
#     accuracy                           0.72       408
#    macro avg       0.72      0.72      0.72       408
# weighted avg       0.72      0.72      0.72       408

# %%
# Define the parameter grid
param_grid_svc2 = {
    'C': [0.01, 0.1, 1, 10, 100]
}

# Set up the grid search
grid_search_svc2 = GridSearchCV(SVC2, param_grid_svc2, cv=5, scoring='accuracy')

# Fit the model
grid_search_svc2.fit(X_train_tfvec, y_train)

# Get the best model and parameters
best_svc2 = grid_search_svc2.best_estimator_
print(f"Best parameters: {grid_search_svc2.best_params_}")
print(f"Best cross-validation accuracy: {grid_search_svc2.best_score_}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Best parameters: {'C': 1}
# Best cross-validation accuracy: 0.698975628975066
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
best_svc2
# Out:
# LinearSVC(C=1)

# %%
best_svc2.fit(X_train_tfvec, y_train)
# Out:
# LinearSVC(C=1)

# %%
print(confusion_matrix(best_svc2.predict(X_test_tfvec),y_test))
print(classification_report(best_svc2.predict(X_test_tfvec),y_test))
# Out:
# [[ 90  16   7]
#  [ 17 108  26]
#  [ 32  18  94]]
#               precision    recall  f1-score   support
#
#    angriness       0.65      0.80      0.71       113
#    happiness       0.76      0.72      0.74       151
#      sadness       0.74      0.65      0.69       144
#
#     accuracy                           0.72       408
#    macro avg       0.72      0.72      0.72       408
# weighted avg       0.72      0.72      0.72       408

# %%
# Create the XGBoost classifier
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')

# %%
# Fit the model
xgb_model.fit(X_train_tfvec, y_train_encoded)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:30:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
# ...

# %%
print(confusion_matrix(xgb_model.predict(X_test_tfvec),y_test_encoded))
print(classification_report(xgb_model.predict(X_test_tfvec),y_test_encoded))
# Out:
# [[86 21  9]
#  [14 96 22]
#  [39 25 96]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.74      0.67       116
#            1       0.68      0.73      0.70       132
#            2       0.76      0.60      0.67       160
#
#     accuracy                           0.68       408
#    macro avg       0.68      0.69      0.68       408
# weighted avg       0.69      0.68      0.68       408

# %%
# Initialize the base estimator
base_estimator = DecisionTreeClassifier(max_depth=1)  # Stump

# %%
# Create the AdaBoost classifier
ada_model = AdaBoostClassifier(n_estimators=50, random_state=42)

# %%
ada_model.fit(X_train_tfvec, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier(random_state=42)

# %%
print(confusion_matrix(ada_model.predict(X_test_tfvec),y_test))
print(classification_report(ada_model.predict(X_test_tfvec),y_test))
# Out:
# [[108  55  59]
#  [ 21  74  22]
#  [ 10  13  46]]
#               precision    recall  f1-score   support
#
#    angriness       0.78      0.49      0.60       222
#    happiness       0.52      0.63      0.57       117
#      sadness       0.36      0.67      0.47        69
#
#     accuracy                           0.56       408
#    macro avg       0.55      0.60      0.55       408
# weighted avg       0.63      0.56      0.57       408

# %%
# Define the Gradient Boosting model
gb = GradientBoostingClassifier()

# %%
gb.fit(X_train_tfvec, y_train)
# Out:
# GradientBoostingClassifier()

# %%
print(confusion_matrix(gb.predict(X_test_tfvec),y_test))
print(classification_report(gb.predict(X_test_tfvec),y_test))
# Out:
# [[109  34  41]
#  [ 15  89  23]
#  [ 15  19  63]]
#               precision    recall  f1-score   support
#
#    angriness       0.78      0.59      0.67       184
#    happiness       0.63      0.70      0.66       127
#      sadness       0.50      0.65      0.56        97
#
#     accuracy                           0.64       408
#    macro avg       0.64      0.65      0.63       408
# weighted avg       0.67      0.64      0.64       408

# %%
import random
import nltk
from nltk.corpus import wordnet

# Ensure you have the necessary NLTK resources
nltk.download('wordnet')

def get_synonyms(word):
    synonyms = wordnet.synsets(word)
    if not synonyms:
        return []
    return list(set([lemma.name() for synonym in synonyms for lemma in synonym.lemmas()]))

def synonym_replacement(sentence, n):
    words = sentence.split()
    new_words = words.copy()
    random_word_list = list(set([word for word in words if get_synonyms(word)]))
    random.shuffle(random_word_list)

    num_replaced = 0
    for random_word in random_word_list:
        synonyms = get_synonyms(random_word)
        if synonyms:
            synonym = random.choice(synonyms)
            new_words = [synonym if word == random_word else word for word in new_words]
            num_replaced += 1
        if num_replaced >= n:
            break

    return ' '.join(new_words)

def random_insertion(sentence, n):
    words = sentence.split()
    new_words = words.copy()
    for _ in range(n):
        if len(words) == 0:  # Check if there are words to choose from
            break

        synonym = get_synonyms(random.choice(words))
        if synonym:
            insert_pos = random.randint(0, len(new_words))  # Allow inserting at the end
            new_words.insert(insert_pos, random.choice(synonym))
    return ' '.join(new_words)

def random_swap(sentence, n):
    words = sentence.split()
    new_words = words.copy()
    if len(words) < 2:  # Ensure there are at least 2 words to swap
        return sentence

    for _ in range(n):
        idx1, idx2 = random.sample(range(len(words)), 2)
        new_words[idx1], new_words[idx2] = new_words[idx2], new_words[idx1]
    return ' '.join(new_words)

def random_deletion(sentence, p=0.3):
    words = sentence.split()
    if len(words) <= 1:  # If there's only one word, don't delete it
        return sentence

    # Remove words with probability p
    new_words = [word for word in words if random.uniform(0, 1) > p]

    # Check if new_words is empty; if so, return the original sentence or the first word
    if not new_words:
        return words[0]  # Return the first word to avoid empty sentence

    return ' '.join(new_words)

def eda(sentence, num_aug=4):
    augmented_sentences = []
    augmented_sentences.append(synonym_replacement(sentence, n=2))
    augmented_sentences.append(random_insertion(sentence, n=2))
    augmented_sentences.append(random_swap(sentence, n=2))
    augmented_sentences.append(random_deletion(sentence, p=0.3))
    return augmented_sentences
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Augment the dataset
augmented_sentences = []
augmented_labels = []

for index, row in df.iterrows():
    sentence = row['content']
    label = row['intensity']

    # Generate augmented sentences for each row
    aug_sentences = eda(sentence, num_aug=4)

    # Append the original and augmented sentences along with labels
    augmented_sentences.append(sentence)  # Original sentence
    augmented_labels.append(label)  # Original label

    # Add augmented data
    augmented_sentences.extend(aug_sentences)
    augmented_labels.extend([label] * len(aug_sentences))

# Create a new DataFrame with augmented data
augmented_df = pd.DataFrame({
    'content': augmented_sentences,
    'intensity': augmented_labels
})

# Combine original and augmented data (optional, if you want to include the original data too)
final_df = pd.concat([df, augmented_df])

# Show the result
print(final_df)
# Out:
#                                                                                               content  \
# 0                                     Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                      Not available for busy people☺
# 2      I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                       Everything is getting expensive except some people, they are getting cheaper.
# 4                                                        My phone screen is brighter than my future 🙁
# ...                                                                                               ...
# 10190                             Instead of wiping your tears, wipe away the people who caused them.
# 10191                             or_else of wiping your tears, wipe away the masses who caused them.
# ...

# %%
augmented_df
# Out:
#                                                                            content  \
# 0                  Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1             Sometimes I’m non angry, I’m detriment and there’s a big difference.
# 2                  Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 3                  Sometimes I’m not angry, I’m difference. big there’s a and hurt
# 4                                                         not angry, and there’s a
# ...                                                                            ...
# 10190          Instead of wiping your tears, wipe away the people who caused them.
# 10191          or_else of wiping your tears, wipe away the masses who caused them.
# 10192  Instead of wiping your tears, wipe away the people or_else who caused them.
# 10193          your of wipe Instead tears, wiping away the people who caused them.
# ...

# %%
final_df
# Out:
#                                                                                               content  \
# 0                                     Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                      Not available for busy people☺
# 2      I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                       Everything is getting expensive except some people, they are getting cheaper.
# 4                                                        My phone screen is brighter than my future 🙁
# ...                                                                                               ...
# 10190                             Instead of wiping your tears, wipe away the people who caused them.
# 10191                             or_else of wiping your tears, wipe away the masses who caused them.
# ...

# %%
final_df.shape
# Out:
# (12234, 2)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12234 entries, 0 to 10194
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   content    12234 non-null  object
#  1   intensity  12234 non-null  object
# dtypes: object(2)
# memory usage: 286.7+ KB

# %%
final_df.isna().sum()/len(df) * 100
# Out:
# content      0.0
# intensity    0.0
# dtype: float64

# %%
final_df.duplicated().sum()
# Out:
# 2991

# %%
#check for the target class counts
label_dist = final_df['intensity'].value_counts().to_dict()
fig = plt.figure(figsize = (10, 5))
ax = plt.bar(label_dist.keys(), label_dist.values(), width=0.25)
plt.xticks([0,1,2])
plt.xlabel("Sentiment")
plt.ylabel("Content Count")
plt.show()

# %%
#check for the length of the reveiws
final_df['length']=final_df['content'].apply(lambda x: len(x.split(' ')))

# %%
final_df.head(10)
# Out:
#                                                                                                                                          content  \
# 0                                                                                Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                                                                 Not available for busy people☺
# 2                                                 I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                                                                  Everything is getting expensive except some people, they are getting cheaper.
# 4                                                                                                   My phone screen is brighter than my future 🙁
# ...

# %%
#avg. length for angriness, happiness and sadness reveiews
print(round(final_df[final_df['intensity']=='angriness']['length'].mean()))
print(round(final_df[final_df['intensity']=='happiness']['length'].mean()))
print(round(final_df[final_df['intensity']=='sadness']['length'].mean()))
# Out:
# 216
# 13
# 445

# %%
#plot the distribution based on the length of the reveiews for each intensity
final_df[final_df['intensity']=='angriness']['length'].plot.hist(bins=15, alpha=0.3, label="angriness")
final_df[final_df['intensity']=='happiness']['length'].plot.hist(bins=15, alpha=1, label="happiness")
final_df[final_df['intensity']=='sadness']['length'].plot.hist(bins=15, alpha=0.3, label="sadness")
plt.xlabel("length")
plt.show()

# %%
STOPWORDS = set(stopwords.words('english'))

# %%
STOPWORDS
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
# helper function to remove stopwords
final_df["clean_content"]=final_df["content"].apply(lambda x: ' '.join([word for word in x.split() if word not in (STOPWORDS)]))

# %%
final_df.head()
# Out:
#                                                                                           content  \
# 0                                 Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                  Not available for busy people☺
# 2  I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                   Everything is getting expensive except some people, they are getting cheaper.
# 4                                                    My phone screen is brighter than my future 🙁
#
#    intensity  length  \
# 0  angriness      11
# 1  angriness       5
# 2  angriness      22
# 3  angriness      11
# 4  angriness       9
#
#                                                   clean_content
# 0         Sometimes I’m angry, I’m hurt there’s big difference.
# 1                                    Not available busy people☺
# ...

# %%
#apply the function on the tweet column
final_df['clean_content'] = final_df['clean_content'].apply(text_clean)

# %%
final_df.head()
# Out:
#                                                                                           content  \
# 0                                 Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                  Not available for busy people☺
# 2  I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                   Everything is getting expensive except some people, they are getting cheaper.
# 4                                                    My phone screen is brighter than my future 🙁
#
#    intensity  length  \
# 0  angriness      11
# 1  angriness       5
# 2  angriness      22
# 3  angriness      11
# 4  angriness       9
#
#                                                   clean_content
# 0         sometimes i m angry  i m hurt there s big difference
# 1                                    not available busy people
# ...

# %%
final_df = final_df.drop('length', axis = 1)

# %%
final_df.head(10)
# Out:
#                                                                                                                                          content  \
# 0                                                                                Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                                                                 Not available for busy people☺
# 2                                                 I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                                                                  Everything is getting expensive except some people, they are getting cheaper.
# 4                                                                                                   My phone screen is brighter than my future 🙁
# ...

# %%
#check for the length of the reveiws
final_df['length']=final_df['clean_content'].apply(lambda x: len(x.split(' ')))

# %%
final_df.head(10)
# Out:
#                                                                                                                                          content  \
# 0                                                                                Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                                                                 Not available for busy people☺
# 2                                                 I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                                                                  Everything is getting expensive except some people, they are getting cheaper.
# 4                                                                                                   My phone screen is brighter than my future 🙁
# ...

# %%
# helper function to remove stopwords
final_df["clean_content"]=final_df["clean_content"].apply(lambda x: ' '.join([word for word in x.split() if word not in (STOPWORDS)]))

# %%
#check for the length of the reveiws
final_df['length']=final_df['clean_content'].apply(lambda x: len(x.split(' ')))

# %%
final_df.head(10)
# Out:
#                                                                                                                                          content  \
# 0                                                                                Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                                                                 Not available for busy people☺
# 2                                                 I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                                                                  Everything is getting expensive except some people, they are getting cheaper.
# 4                                                                                                   My phone screen is brighter than my future 🙁
# ...

# %%
#avg. length for angriness, happiness and sadness reveiews
print(round(final_df[final_df['intensity']=='angriness']['length'].mean()))
print(round(final_df[final_df['intensity']=='happiness']['length'].mean()))
print(round(final_df[final_df['intensity']=='sadness']['length'].mean()))
# Out:
# 12
# 7
# 17

# %%
#plot the distribution based on the length of the reveiews for each intensity
final_df[final_df['intensity']=='angriness']['length'].plot.hist(bins=15, alpha=0.3, label="angriness")
final_df[final_df['intensity']=='happiness']['length'].plot.hist(bins=15, alpha=1, label="happiness")
final_df[final_df['intensity']=='sadness']['length'].plot.hist(bins=15, alpha=0.3, label="sadness")
plt.xlabel("length")
plt.show()

# %%
#frequency count
top_words = 50
#tokenize the tweets into individual tokens
words = nltk.tokenize.word_tokenize(final_df['clean_content'].str.cat(sep=' '))
#list of redundant words to be not considered in the frequency count
filter_words = [word for word in words if word not in STOPWORDS]

# %%
#Use the FreqDist function from nltk for freq count
word_freq = nltk.FreqDist(filter_words)
#create the dataframe for top occuring words
wordfreq_df = pd.DataFrame(word_freq.most_common(top_words),
                    columns=['Word', 'Frequency'])

# %%
wordfreq_df
# Out:
#           Word  Frequency
# 0       people       2221
# 1         love       2155
# 2        angry       1886
# 3        anger       1637
# 4      someone       1563
# 5        never       1555
# 6          one       1523
# 7         life       1390
# 8          xa0       1345
# 9          sad       1303
# 10        like       1291
# 11        make       1267
# 12   sometimes       1215
# 13       heart       1122
# 14      status       1097
# 15   happiness       1028
# 16      person       1001
# 17       smile        978
# 18        hurt        947
# 19      always        943
# 20        care        943
# 21         get        909
# 22    whatsapp        903
# 23        know        892
# 24      things        863
# 25  everything        838
# 26        need        822
# 27        time        796
# 28        much        787
# 29        even        745
# 30          go        743
# 31        want        729
# 32       think        685
# 33        pain        682
# ...

# %%
final_df.head(10)
# Out:
#                                                                                                                                          content  \
# 0                                                                                Sometimes I’m not angry, I’m hurt and there’s a big difference.
# 1                                                                                                                 Not available for busy people☺
# 2                                                 I do not exist to impress the world. I exist to live my life in a way that will make me happy.
# 3                                                                  Everything is getting expensive except some people, they are getting cheaper.
# 4                                                                                                   My phone screen is brighter than my future 🙁
# ...

# %%
#Sentiment Classifier
#split the data into training and test set with balanced split based on target class
X_train, X_test, y_train, y_test = train_test_split(final_df["clean_content"],
                                                    final_df["intensity"],test_size=0.2,
                                                    stratify=final_df['intensity'])

# %%
#check the shape of train and test data
print(X_train.shape[0],X_test.shape[0])
# Out:
# 9787 2447

# %%
#check the class balance in train data
print(y_train.value_counts())
# Out:
# intensity
# happiness    3398
# angriness    3341
# sadness      3048
# Name: count, dtype: int64

# %%
#check the target class balance in test data
print(y_test.value_counts())
# Out:
# intensity
# happiness    850
# angriness    835
# sadness      762
# Name: count, dtype: int64

# %%
# Use the countvectoriser to convert text data into numerical/vector form
vectorizer = CountVectorizer(token_pattern=r'\b\w+\b')
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
# train using Logistic Regression Model
alr1 = LogisticRegression(class_weight='balanced')
alr1.fit(X_train_vec,y_train)
print(confusion_matrix(alr1.predict(X_test_vec),y_test))
print(classification_report(alr1.predict(X_test_vec),y_test))
# Out:
# [[686  27  19]
#  [ 10 771  14]
#  [139  52 729]]
#               precision    recall  f1-score   support
#
#    angriness       0.82      0.94      0.88       732
#    happiness       0.91      0.97      0.94       795
#      sadness       0.96      0.79      0.87       920
#
#     accuracy                           0.89      2447
#    macro avg       0.90      0.90      0.89      2447
# weighted avg       0.90      0.89      0.89      2447

# %%
from sklearn.model_selection import GridSearchCV

param_gridalr1 = {
    'C': [0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'newton-cg', 'saga']
}

grid_searchalr1 = GridSearchCV(alr1, param_gridalr1, cv=5, scoring='accuracy')
grid_searchalr1.fit(X_train_vec, y_train)

# Best model
best_alr1 = grid_searchalr1.best_estimator_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
best_alr1
# Out:
# LogisticRegression(C=10, class_weight='balanced', solver='liblinear')

# %%
best_alr1.fit(X_train_vec, y_train)
# Out:
# LogisticRegression(C=10, class_weight='balanced', solver='liblinear')

# %%
print(confusion_matrix(best_alr1.predict(X_test_vec),y_test))
print(classification_report(best_alr1.predict(X_test_vec),y_test))
# Out:
# [[686  22  18]
#  [  9 785  14]
#  [140  43 730]]
#               precision    recall  f1-score   support
#
#    angriness       0.82      0.94      0.88       726
#    happiness       0.92      0.97      0.95       808
#      sadness       0.96      0.80      0.87       913
#
#     accuracy                           0.90      2447
#    macro avg       0.90      0.91      0.90      2447
# weighted avg       0.91      0.90      0.90      2447

# %%
#train and evaluate the RF classifier model
arf1 = RandomForestClassifier(n_estimators=100)
arf1.fit(X_train_vec,y_train)
print(confusion_matrix(arf1.predict(X_test_vec),y_test))
print(classification_report(arf1.predict(X_test_vec),y_test))
# Out:
# [[694  10  18]
#  [ 13 811  10]
#  [128  29 734]]
#               precision    recall  f1-score   support
#
#    angriness       0.83      0.96      0.89       722
#    happiness       0.95      0.97      0.96       834
#      sadness       0.96      0.82      0.89       891
#
#     accuracy                           0.91      2447
#    macro avg       0.92      0.92      0.91      2447
# weighted avg       0.92      0.91      0.91      2447

# %%
#train and evaluate the Linear Support Vector Classifier model
aSVC1 = LinearSVC()
aSVC1.fit(X_train_vec,y_train)
print(confusion_matrix(aSVC1.predict(X_test_vec),y_test))
print(classification_report(aSVC1.predict(X_test_vec),y_test))
# Out:
# [[685  24  18]
#  [ 12 783  16]
#  [138  43 728]]
#               precision    recall  f1-score   support
#
#    angriness       0.82      0.94      0.88       727
#    happiness       0.92      0.97      0.94       811
#      sadness       0.96      0.80      0.87       909
#
#     accuracy                           0.90      2447
#    macro avg       0.90      0.90      0.90      2447
# weighted avg       0.90      0.90      0.90      2447

# %%
# Define the parameter grid
param_grid_asvc1 = {
    'C': [0.01, 0.1, 1, 10, 100]
}

# Set up the grid search
grid_search_asvc1 = GridSearchCV(aSVC1, param_grid_asvc1, cv=5, scoring='accuracy')

# Fit the model
grid_search_asvc1.fit(X_train_vec, y_train)

# Get the best model and parameters
best_asvc1 = grid_search_asvc1.best_estimator_
print(f"Best parameters: {grid_search_asvc1.best_params_}")
print(f"Best cross-validation accuracy: {grid_search_asvc1.best_score_}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Best parameters: {'C': 1}
# Best cross-validation accuracy: 0.8995611990794942

# %%
best_asvc1
# Out:
# LinearSVC(C=1)

# %%
best_asvc1.fit(X_train_vec, y_train)
# Out:
# LinearSVC(C=1)

# %%
print(confusion_matrix(best_asvc1.predict(X_test_vec),y_test))
print(classification_report(best_asvc1.predict(X_test_vec),y_test))
# Out:
# [[685  24  18]
#  [ 12 783  16]
#  [138  43 728]]
#               precision    recall  f1-score   support
#
#    angriness       0.82      0.94      0.88       727
#    happiness       0.92      0.97      0.94       811
#      sadness       0.96      0.80      0.87       909
#
#     accuracy                           0.90      2447
#    macro avg       0.90      0.90      0.90      2447
# weighted avg       0.90      0.90      0.90      2447

# %%
# Create the XGBoost classifier
axgb_model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the labels to numerical format
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Fit the model
axgb_model.fit(X_train_vec, y_train_encoded)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:29:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
# ...

# %%
print(confusion_matrix(axgb_model.predict(X_test_vec),y_test_encoded))
print(classification_report(axgb_model.predict(X_test_vec),y_test_encoded))
# Out:
# [[798  94 207]
#  [ 13 699  11]
#  [ 24  57 544]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.73      0.83      1099
#            1       0.82      0.97      0.89       723
#            2       0.71      0.87      0.78       625
#
#     accuracy                           0.83      2447
#    macro avg       0.83      0.85      0.83      2447
# weighted avg       0.85      0.83      0.83      2447

# %%
# Use TF-IDF Vectorizer
vectorizertfidf = TfidfVectorizer(use_idf=True, ngram_range=(1, 2))
X_train_tfvec = vectorizertfidf.fit_transform(X_train)
X_test_tfvec = vectorizertfidf.transform(X_test)

# %%
alr2 = LogisticRegression(class_weight='balanced')
alr2.fit(X_train_tfvec,y_train)
#evaluate the performance of logistic model on test data
print(confusion_matrix(alr2.predict(X_test_tfvec),y_test))
print(classification_report(alr2.predict(X_test_tfvec),y_test))
# Out:
# [[697  16  13]
#  [  7 799  13]
#  [131  35 736]]
#               precision    recall  f1-score   support
#
#    angriness       0.83      0.96      0.89       726
#    happiness       0.94      0.98      0.96       819
#      sadness       0.97      0.82      0.88       902
#
#     accuracy                           0.91      2447
#    macro avg       0.91      0.92      0.91      2447
# weighted avg       0.92      0.91      0.91      2447

# %%
from sklearn.model_selection import GridSearchCV

param_gridalr2 = {
    'C': [0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'newton-cg', 'saga']
}

grid_searchalr2 = GridSearchCV(alr2, param_gridalr2, cv=5, scoring='accuracy')
grid_searchalr2.fit(X_train_tfvec, y_train)

# Best model
best_alr2 = grid_searchalr2.best_estimator_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
best_alr2
# Out:
# LogisticRegression(C=100, class_weight='balanced', solver='liblinear')

# %%
best_alr2.fit(X_train_tfvec, y_train)
# Out:
# LogisticRegression(C=100, class_weight='balanced', solver='liblinear')

# %%
print(confusion_matrix(best_alr2.predict(X_test_tfvec),y_test))
print(classification_report(best_alr2.predict(X_test_tfvec),y_test))
# Out:
# [[705   9  11]
#  [  3 824  14]
#  [127  17 737]]
#               precision    recall  f1-score   support
#
#    angriness       0.84      0.97      0.90       725
#    happiness       0.97      0.98      0.97       841
#      sadness       0.97      0.84      0.90       881
#
#     accuracy                           0.93      2447
#    macro avg       0.93      0.93      0.93      2447
# weighted avg       0.93      0.93      0.93      2447

# %%
#train and evaluate the RF classifier model
arf2 = RandomForestClassifier(n_estimators=100)
arf2.fit(X_train_tfvec,y_train)
print(confusion_matrix(arf2.predict(X_test_tfvec),y_test))
print(classification_report(arf2.predict(X_test_tfvec),y_test))
# Out:
# [[694  16  15]
#  [  4 805  13]
#  [137  29 734]]
#               precision    recall  f1-score   support
#
#    angriness       0.83      0.96      0.89       725
#    happiness       0.95      0.98      0.96       822
#      sadness       0.96      0.82      0.88       900
#
#     accuracy                           0.91      2447
#    macro avg       0.91      0.92      0.91      2447
# weighted avg       0.92      0.91      0.91      2447

# %%
#train and evaluate the Linear Support Vector Classifier model
aSVC2 = LinearSVC()
aSVC2.fit(X_train_tfvec,y_train)
print(confusion_matrix(aSVC2.predict(X_test_tfvec),y_test))
print(classification_report(aSVC2.predict(X_test_tfvec),y_test))
# Out:
# [[705   9  12]
#  [  3 826  12]
#  [127  15 738]]
#               precision    recall  f1-score   support
#
#    angriness       0.84      0.97      0.90       726
#    happiness       0.97      0.98      0.98       841
#      sadness       0.97      0.84      0.90       880
#
#     accuracy                           0.93      2447
#    macro avg       0.93      0.93      0.93      2447
# weighted avg       0.93      0.93      0.93      2447

# %%
# Define the parameter grid
param_grid_asvc2 = {
    'C': [0.01, 0.1, 1, 10, 100]
}

# Set up the grid search
grid_search_asvc2 = GridSearchCV(aSVC2, param_grid_asvc2, cv=5, scoring='accuracy')

# Fit the model
grid_search_asvc2.fit(X_train_tfvec, y_train)

# Get the best model and parameters
best_asvc2 = grid_search_asvc2.best_estimator_
print(f"Best parameters: {grid_search_asvc2.best_params_}")
print(f"Best cross-validation accuracy: {grid_search_asvc2.best_score_}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Best parameters: {'C': 1}
# Best cross-validation accuracy: 0.9279661861795716
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
best_asvc2
# Out:
# LinearSVC(C=1)

# %%
best_asvc2.fit(X_train_tfvec, y_train)
# Out:
# LinearSVC(C=1)

# %%
print(confusion_matrix(best_asvc2.predict(X_test_tfvec),y_test))
print(classification_report(best_asvc2.predict(X_test_tfvec),y_test))
# Out:
# [[705   9  12]
#  [  3 826  12]
#  [127  15 738]]
#               precision    recall  f1-score   support
#
#    angriness       0.84      0.97      0.90       726
#    happiness       0.97      0.98      0.98       841
#      sadness       0.97      0.84      0.90       880
#
#     accuracy                           0.93      2447
#    macro avg       0.93      0.93      0.93      2447
# weighted avg       0.93      0.93      0.93      2447
